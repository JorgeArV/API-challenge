# %%
#Observable trends
#The "Southern Hemisphere - Wind Speed (mph) vs. Latitude" and "Northern Hemisphere - Wind Speed (mph) vs. Latitude" linear regression equations have the two slopes that are the closest to 0 (0.07 & -0.09 respectively). This indicates that there is almost no impact of latitude on the wind speed that is recorded in a city.
#It is interesting to visually inspect and compare the "City Latitude vs. Cloudiness" scatterplot and the "City Latitude vs. Wind Speed" scatterplot. It is safe to assume that latitude has little impact on these two variables. However, they behave differently. Cloudiness values are all over the place, with no discernable trend. However, it seems that there is a threshold for wind speed: Most cities have wind speeds below 15 mph with only a few of them going above this value. 
#The Northern Hemisphere - Temperature (F) vs.Latitude" linear regression analysis provides overwhelming proof that latitude has an impact on the temperature for those cities in the northern hemisphere of the world. The slope value of the linear regression equation is -1, which means that it is almost certain that temperatures will decrease the further in the north a city is located.

# %%
#Importing dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

#API Key
API_key = "6726ced767ce0919b0ef1ea275fbfc29"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#We want to ensure that we get cities from around the world, not just 1 region. As we are working with latitude and longitude, we divide the world
#we divide the world in four quadrants:


#QUADRANT 1 - Southwest quadrant 
# We create a set of random lat and lng combinations. We adjust the low and high values of the latitude and longitude to encompass
#ONLY quadrant #1:
lats = np.random.uniform(low=-90.000, high=0.000, size=600)
lngs = np.random.uniform(low=-180.000, high=0.000, size=600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

        
#QUADRANT 2 - Northwest quadrant 
# We create a set of random lat and lng combinations. We adjust the low and high values of the latitude and longitude to encompass
#ONLY quadrant #2:

lats = np.random.uniform(low=0.000, high=90.000, size=600)
lngs = np.random.uniform(low=-180.000, high=0.000, size=600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#QUADRANT 3 - Northwest quadrant 
# We create a set of random lat and lng combinations. We adjust the low and high values of the latitude and longitude to encompass
#ONLY quadrant #3:        
        
lats = np.random.uniform(low=0.000, high=90.000, size=600)
lngs = np.random.uniform(low=0.000, high=180.000, size=600)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

lats = np.random.uniform(low=-90.000, high=0.000, size=600)
lngs = np.random.uniform(low=-0.000, high=180.000, size=600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#cities
# Out:
# 891

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={API_key}&q="

# %%
#url1 = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={API_key}&q=dikson"
# set up lists to hold reponse info
cities1 = []
cloudiness = []
countries = []
dates = []
humidity = []
lats = []
lng = []
max_temp = []
speed_w = []
counter = 50
record_counter = 1
set_counter = 1 

print("Beginning data retreival" + "\n" + "----------------------------" + "\n")

# Loop through the list of cities and perform a request for data on each
for x in cities:
    if len(cities1) <= counter: 
        try:
            response = requests.get(url + x).json()
            cities1.append(response["name"])
            cloudiness.append(response["clouds"]["all"])
            countries.append(response["sys"]["country"])
            dates.append(response["dt"])
            humidity.append(response["main"]["humidity"])
            lats.append(response["coord"]["lat"])
            lng.append(response["coord"]["lon"])
            max_temp.append(response["main"]["temp_max"])
            speed_w.append(response["wind"]["speed"])
            print(f"Processing record {record_counter} of set {set_counter} | {x}")
            record_counter = record_counter+1      
    
        except:
            print("City not found. Skipping....")      
            pass
    else:
        time.sleep(3)
        
        try:
            record_counter = 1
            set_counter = set_counter + 1      
            response = requests.get(url + x).json()
            cities1.append(response["name"])
            cloudiness.append(response["clouds"]["all"])
            countries.append(response["sys"]["country"])
            dates.append(response["dt"])
            humidity.append(response["main"]["humidity"])
            lats.append(response["coord"]["lat"])
            lng.append(response["coord"]["lon"])
            max_temp.append(response["main"]["temp_max"])
            speed_w.append(response["wind"]["speed"])
            print(f"Processing record {record_counter} of set {set_counter} | {x}")
            record_counter = record_counter + 1      
    
        except:
            print("City not found. Skipping....")      
            pass
        
        counter = counter + 50
# Out:
# Beginning data retreival
# ----------------------------
#
# Processing record 1 of set 1 | punta arenas
# Processing record 2 of set 1 | arraial do cabo
# Processing record 3 of set 1 | jamestown
# Processing record 4 of set 1 | avarua
# Processing record 5 of set 1 | cabrobo
# Processing record 6 of set 1 | castro
# Processing record 7 of set 1 | rikitea
# Processing record 8 of set 1 | viedma
# Processing record 9 of set 1 | hermanus
# Processing record 10 of set 1 | mataura
# Processing record 11 of set 1 | sao geraldo do araguaia
# Processing record 12 of set 1 | sao jose da coroa grande
# Processing record 13 of set 1 | vaini
# Processing record 14 of set 1 | caravelas
# City not found. Skipping....
# Processing record 15 of set 1 | puerto quijarro
# Processing record 16 of set 1 | ushuaia
# Processing record 17 of set 1 | lebu
# Processing record 18 of set 1 | san patricio
# Processing record 19 of set 1 | atuona
# Processing record 20 of set 1 | mar del plata
# Processing record 21 of set 1 | pisco
# Processing record 22 of set 1 | ancud
# Processing record 23 of set 1 | seabra
# Processing record 24 of set 1 | cape town
# City not found. Skipping....
# Processing record 25 of set 1 | vila velha
# Processing record 26 of set 1 | alofi
# Processing record 27 of set 1 | iaciara
# Processing record 28 of set 1 | talcahuano
# Processing record 29 of set 1 | puerto ayora
# Processing record 30 of set 1 | hualmay
# Processing record 31 of set 1 | san pedro
# Processing record 32 of set 1 | la paz
# Processing record 33 of set 1 | chuy
# Processing record 34 of set 1 | pangoa
# Processing record 35 of set 1 | coihaique
# Processing record 36 of set 1 | coquimbo
# Processing record 37 of set 1 | san rafael
# Processing record 38 of set 1 | faanui
# Processing record 39 of set 1 | pontes e lacerda
# Processing record 40 of set 1 | alenquer
# Processing record 41 of set 1 | chivilcoy
# Processing record 42 of set 1 | huarmey
# Processing record 43 of set 1 | governador valadares
# Processing record 44 of set 1 | georgetown
# City not found. Skipping....
# Processing record 45 of set 1 | general roca
# City not found. Skipping....
# Processing record 46 of set 1 | humaita
# Processing record 47 of set 1 | rio gallegos
# Processing record 48 of set 1 | cidreira
# Processing record 49 of set 1 | tautira
# Processing record 50 of set 1 | rawson
# Processing record 51 of set 1 | tabou
# Processing record 1 of set 2 | san francisco
# City not found. Skipping....
# Processing record 2 of set 2 | saquarema
# Processing record 3 of set 2 | san borja
# Processing record 4 of set 2 | yurimaguas
# Processing record 5 of set 2 | manicore
# City not found. Skipping....
# Processing record 6 of set 2 | urucara
# Processing record 7 of set 2 | aracaju
# Processing record 8 of set 2 | princesa isabel
# Processing record 9 of set 2 | beberibe
# Processing record 10 of set 2 | takoradi
# Processing record 11 of set 2 | los andes
# Processing record 12 of set 2 | taltal
# Processing record 13 of set 2 | parana
# Processing record 14 of set 2 | melo
# Processing record 15 of set 2 | porto walter
# Processing record 16 of set 2 | santiago del estero
# Processing record 17 of set 2 | san juan
# Processing record 18 of set 2 | anastacio
# Processing record 19 of set 2 | tiarei
# Processing record 20 of set 2 | san ramon de la nueva oran
# Processing record 21 of set 2 | alta floresta
# Processing record 22 of set 2 | salinas
# Processing record 23 of set 2 | rocha
# Processing record 24 of set 2 | camana
# Processing record 25 of set 2 | acari
# Processing record 26 of set 2 | laguna
# Processing record 27 of set 2 | rio grande
# Processing record 28 of set 2 | boca do acre
# Processing record 29 of set 2 | morros
# Processing record 30 of set 2 | imbituba
# Processing record 31 of set 2 | san cristobal
# Processing record 32 of set 2 | porto seguro
# Processing record 33 of set 2 | amontada
# Processing record 34 of set 2 | sao marcos
# Processing record 35 of set 2 | venado tuerto
# Processing record 36 of set 2 | lima
# Processing record 37 of set 2 | papara
# Processing record 38 of set 2 | sao joao da barra
# Processing record 39 of set 2 | bella union
# Processing record 40 of set 2 | chicama
# City not found. Skipping....
# Processing record 41 of set 2 | santa cruz
# Processing record 42 of set 2 | huancavelica
# Processing record 43 of set 2 | valparaiso
# Processing record 44 of set 2 | brae
# Processing record 45 of set 2 | panama city
# Processing record 46 of set 2 | kapaa
# Processing record 47 of set 2 | kirkland lake
# Processing record 48 of set 2 | barrow
# Processing record 49 of set 2 | kodiak
# Processing record 50 of set 2 | gouyave
# Processing record 1 of set 3 | monrovia
# City not found. Skipping....
# Processing record 2 of set 3 | monroe
# City not found. Skipping....
# Processing record 3 of set 3 | klaksvik
# Processing record 4 of set 3 | port hardy
# Processing record 5 of set 3 | columbus
# Processing record 6 of set 3 | saint george
# Processing record 7 of set 3 | haines junction
# Processing record 8 of set 3 | sicamous
# Processing record 9 of set 3 | moose factory
# Processing record 10 of set 3 | codrington
# Processing record 11 of set 3 | puerto carreno
# Processing record 12 of set 3 | san andres
# Processing record 13 of set 3 | nome
# Processing record 14 of set 3 | barcelos
# Processing record 15 of set 3 | upernavik
# Processing record 16 of set 3 | hofn
# Processing record 17 of set 3 | pangnirtung
# Processing record 18 of set 3 | matagami
# Processing record 19 of set 3 | hilo
# Processing record 20 of set 3 | clyde river
# Processing record 21 of set 3 | ponta do sol
# City not found. Skipping....
# Processing record 22 of set 3 | tasiilaq
# Processing record 23 of set 3 | nzerekore
# Processing record 24 of set 3 | yellowknife
# Processing record 25 of set 3 | ilulissat
# Processing record 26 of set 3 | rabat
# Processing record 27 of set 3 | cabo san lucas
# Processing record 28 of set 3 | touros
# Processing record 29 of set 3 | maniitsoq
# Processing record 30 of set 3 | grindavik
# Processing record 31 of set 3 | shelburne
# City not found. Skipping....
# Processing record 32 of set 3 | ribeira grande
# Processing record 33 of set 3 | sitka
# City not found. Skipping....
# Processing record 34 of set 3 | oistins
# Processing record 35 of set 3 | bubaque
# Processing record 36 of set 3 | bradford
# Processing record 37 of set 3 | golden
# Processing record 38 of set 3 | norman wells
# Processing record 39 of set 3 | qaanaaq
# Processing record 40 of set 3 | provideniya
# Processing record 41 of set 3 | virginia beach
# Processing record 42 of set 3 | fortuna
# Processing record 43 of set 3 | torbay
# Processing record 44 of set 3 | pizarro
# Processing record 45 of set 3 | guerrero negro
# Processing record 46 of set 3 | dallas
# City not found. Skipping....
# Processing record 47 of set 3 | bethel
# Processing record 48 of set 3 | paamiut
# Processing record 49 of set 3 | poplar bluff
# Processing record 50 of set 3 | lompoc
# Processing record 1 of set 4 | herrin
# Processing record 2 of set 4 | lagoa
# Processing record 3 of set 4 | cumberland
# Processing record 4 of set 4 | taoudenni
# Processing record 5 of set 4 | thompson
# Processing record 6 of set 4 | la ronge
# Processing record 7 of set 4 | sturgis
# Processing record 8 of set 4 | saint-raymond
# Processing record 9 of set 4 | qaqortoq
# Processing record 10 of set 4 | nelson
# Processing record 11 of set 4 | bon air
# Processing record 12 of set 4 | tuktoyaktuk
# Processing record 13 of set 4 | lufkin
# Processing record 14 of set 4 | lavrentiya
# Processing record 15 of set 4 | peachland
# Processing record 16 of set 4 | maturin
# Processing record 17 of set 4 | new richmond
# Processing record 18 of set 4 | cloquet
# Processing record 19 of set 4 | cayenne
# Processing record 20 of set 4 | wabash
# City not found. Skipping....
# Processing record 21 of set 4 | mosquera
# Processing record 22 of set 4 | vicente guerrero
# Processing record 23 of set 4 | aklavik
# Processing record 24 of set 4 | ponta delgada
# Processing record 25 of set 4 | thunder bay
# Processing record 26 of set 4 | saint-francois
# Processing record 27 of set 4 | jeremie
# Processing record 28 of set 4 | vestmannaeyjar
# Processing record 29 of set 4 | el tigre
# Processing record 30 of set 4 | carutapera
# Processing record 31 of set 4 | kahului
# Processing record 32 of set 4 | lethem
# Processing record 33 of set 4 | san quintin
# Processing record 34 of set 4 | dingle
# Processing record 35 of set 4 | kenora
# Processing record 36 of set 4 | ribeira brava
# Processing record 37 of set 4 | saint andrews
# Processing record 38 of set 4 | half moon bay
# Processing record 39 of set 4 | sinnamary
# City not found. Skipping....
# Processing record 40 of set 4 | abbotsford
# Processing record 41 of set 4 | banamba
# Processing record 42 of set 4 | dalvik
# Processing record 43 of set 4 | iqaluit
# Processing record 44 of set 4 | siguiri
# Processing record 45 of set 4 | acarau
# Processing record 46 of set 4 | goderich
# Processing record 47 of set 4 | inuvik
# Processing record 48 of set 4 | bonthe
# Processing record 49 of set 4 | yucca valley
# Processing record 50 of set 4 | vila franca do campo
# Processing record 1 of set 5 | miguel hidalgo
# Processing record 2 of set 5 | intipuca
# Processing record 3 of set 5 | elko
# Processing record 4 of set 5 | guarda
# Processing record 5 of set 5 | great falls
# Processing record 6 of set 5 | constitucion
# Processing record 7 of set 5 | saint anthony
# Processing record 8 of set 5 | ketchikan
# Processing record 9 of set 5 | manitouwadge
# Processing record 10 of set 5 | muros
# Processing record 11 of set 5 | assiniboia
# Processing record 12 of set 5 | champerico
# Processing record 13 of set 5 | east wenatchee bench
# Processing record 14 of set 5 | nanortalik
# Processing record 15 of set 5 | high prairie
# Processing record 16 of set 5 | seaford
# Processing record 17 of set 5 | la cruz
# Processing record 18 of set 5 | fairbanks
# Processing record 19 of set 5 | marrakesh
# Processing record 20 of set 5 | haverhill
# Processing record 21 of set 5 | paraiso
# Processing record 22 of set 5 | tecoanapa
# Processing record 23 of set 5 | araouane
# City not found. Skipping....
# Processing record 24 of set 5 | fort nelson
# Processing record 25 of set 5 | mackenzie
# Processing record 26 of set 5 | nuuk
# Processing record 27 of set 5 | bahia honda
# Processing record 28 of set 5 | santa rita
# Processing record 29 of set 5 | barahona
# City not found. Skipping....
# Processing record 30 of set 5 | port arthur
# Processing record 31 of set 5 | saint-augustin
# Processing record 32 of set 5 | puerto colombia
# Processing record 33 of set 5 | douglas
# Processing record 34 of set 5 | narsaq
# City not found. Skipping....
# Processing record 35 of set 5 | manaure
# Processing record 36 of set 5 | upata
# Processing record 37 of set 5 | ixtapa
# Processing record 38 of set 5 | akureyri
# Processing record 39 of set 5 | chihuahua
# Processing record 40 of set 5 | rincon
# Processing record 41 of set 5 | dorado
# Processing record 42 of set 5 | aguililla
# Processing record 43 of set 5 | acapulco
# Processing record 44 of set 5 | fort frances
# Processing record 45 of set 5 | revelstoke
# Processing record 46 of set 5 | buenos aires
# Processing record 47 of set 5 | los llanos de aridane
# Processing record 48 of set 5 | kirkwall
# Processing record 49 of set 5 | two rivers
# Processing record 50 of set 5 | oranjestad
# Processing record 1 of set 6 | atar
# Processing record 2 of set 6 | gallup
# Processing record 3 of set 6 | rapid valley
# Processing record 4 of set 6 | egvekinot
# Processing record 5 of set 6 | new milford
# Processing record 6 of set 6 | san luis
# Processing record 7 of set 6 | caceres
# Processing record 8 of set 6 | punto fijo
# Processing record 9 of set 6 | saint-ambroise
# Processing record 10 of set 6 | magalia
# Processing record 11 of set 6 | husavik
# Processing record 12 of set 6 | bolivar
# Processing record 13 of set 6 | gardendale
# Processing record 14 of set 6 | sao filipe
# Processing record 15 of set 6 | porto novo
# Processing record 16 of set 6 | san rafael del sur
# Processing record 17 of set 6 | salinopolis
# Processing record 18 of set 6 | college
# Processing record 19 of set 6 | garachine
# Processing record 20 of set 6 | hastings
# Processing record 21 of set 6 | killam
# Processing record 22 of set 6 | itarema
# Processing record 23 of set 6 | carballo
# Processing record 24 of set 6 | mapiripan
# Processing record 25 of set 6 | bondoukou
# Processing record 26 of set 6 | pochutla
# Processing record 27 of set 6 | san mateo del mar
# Processing record 28 of set 6 | asfi
# Processing record 29 of set 6 | peniche
# Processing record 30 of set 6 | paredon
# Processing record 31 of set 6 | la sarre
# Processing record 32 of set 6 | dire
# Processing record 33 of set 6 | arona
# Processing record 34 of set 6 | sisimiut
# Processing record 35 of set 6 | sibanicu
# Processing record 36 of set 6 | catalina foothills
# Processing record 37 of set 6 | mana
# Processing record 38 of set 6 | bucerias
# Processing record 39 of set 6 | covington
# Processing record 40 of set 6 | cape canaveral
# Processing record 41 of set 6 | rossland
# Processing record 42 of set 6 | dabakala
# Processing record 43 of set 6 | hamilton
# City not found. Skipping....
# Processing record 44 of set 6 | atikokan
# Processing record 45 of set 6 | santa pola
# Processing record 46 of set 6 | washougal
# Processing record 47 of set 6 | puerto baquerizo moreno
# Processing record 48 of set 6 | lenoir
# Processing record 49 of set 6 | kayes
# Processing record 50 of set 6 | marsh harbour
# Processing record 1 of set 7 | alice town
# Processing record 2 of set 7 | kangaba
# Processing record 3 of set 7 | tucuma
# Processing record 4 of set 7 | bafoulabe
# Processing record 5 of set 7 | juneau
# Processing record 6 of set 7 | flin flon
# Processing record 7 of set 7 | nizwa
# Processing record 8 of set 7 | port blair
# Processing record 9 of set 7 | pavilosta
# Processing record 10 of set 7 | sur
# Processing record 11 of set 7 | sanchor
# Processing record 12 of set 7 | alugan
# Processing record 13 of set 7 | nenjiang
# Processing record 14 of set 7 | dikson
# Processing record 15 of set 7 | nove davydkovo
# Processing record 16 of set 7 | san policarpo
# Processing record 17 of set 7 | kaohsiung
# Processing record 18 of set 7 | sfantu gheorghe
# Processing record 19 of set 7 | saskylakh
# Processing record 20 of set 7 | chokurdakh
# City not found. Skipping....
# Processing record 21 of set 7 | severo-kurilsk
# Processing record 22 of set 7 | provins
# Processing record 23 of set 7 | mankera
# Processing record 24 of set 7 | talnakh
# Processing record 25 of set 7 | podgornoye
# Processing record 26 of set 7 | kyra
# Processing record 27 of set 7 | khatanga
# Processing record 28 of set 7 | butaritari
# Processing record 29 of set 7 | raudeberg
# Processing record 30 of set 7 | marzuq
# Processing record 31 of set 7 | pemangkat
# Processing record 32 of set 7 | thanh hoa
# Processing record 33 of set 7 | pevek
# Processing record 34 of set 7 | sakaiminato
# Processing record 35 of set 7 | bilibino
# Processing record 36 of set 7 | panjakent
# Processing record 37 of set 7 | wakkanai
# Processing record 38 of set 7 | lieksa
# Processing record 39 of set 7 | marsaxlokk
# City not found. Skipping....
# Processing record 40 of set 7 | changji
# Processing record 41 of set 7 | cherskiy
# Processing record 42 of set 7 | raipur
# Processing record 43 of set 7 | tigil
# City not found. Skipping....
# Processing record 44 of set 7 | katsuura
# Processing record 45 of set 7 | batticaloa
# Processing record 46 of set 7 | nikolskoye
# Processing record 47 of set 7 | dosso
# City not found. Skipping....
# Processing record 48 of set 7 | kyaikkami
# Processing record 49 of set 7 | mayya
# Processing record 50 of set 7 | sri aman
# Processing record 1 of set 8 | krasnoyarskaya
# Processing record 2 of set 8 | ornskoldsvik
# City not found. Skipping....
# Processing record 3 of set 8 | kalmunai
# Processing record 4 of set 8 | mabay
# City not found. Skipping....
# Processing record 5 of set 8 | meulaboh
# Processing record 6 of set 8 | aksu
# Processing record 7 of set 8 | maloy
# Processing record 8 of set 8 | yerbogachen
# Processing record 9 of set 8 | jertih
# Processing record 10 of set 8 | salalah
# Processing record 11 of set 8 | yuyao
# Processing record 12 of set 8 | sam chuk
# City not found. Skipping....
# Processing record 13 of set 8 | huilong
# Processing record 14 of set 8 | podporozhye
# Processing record 15 of set 8 | shimanovsk
# City not found. Skipping....
# Processing record 16 of set 8 | hami
# Processing record 17 of set 8 | changli
# Processing record 18 of set 8 | deputatskiy
# Processing record 19 of set 8 | kyzyl-suu
# Processing record 20 of set 8 | catuday
# Processing record 21 of set 8 | altay
# Processing record 22 of set 8 | kumbo
# Processing record 23 of set 8 | vanimo
# Processing record 24 of set 8 | hirara
# Processing record 25 of set 8 | yushala
# Processing record 26 of set 8 | riyadh
# Processing record 27 of set 8 | ubinskoye
# Processing record 28 of set 8 | barwadih
# Processing record 29 of set 8 | balykshi
# Processing record 30 of set 8 | leningradskiy
# Processing record 31 of set 8 | bara
# Processing record 32 of set 8 | kutum
# Processing record 33 of set 8 | vostok
# Processing record 34 of set 8 | gravdal
# Processing record 35 of set 8 | muli
# Processing record 36 of set 8 | moyale
# Processing record 37 of set 8 | dolzhanskaya
# Processing record 38 of set 8 | robe
# Processing record 39 of set 8 | mizdah
# City not found. Skipping....
# Processing record 40 of set 8 | parabel
# Processing record 41 of set 8 | mizan teferi
# Processing record 42 of set 8 | mehamn
# Processing record 43 of set 8 | tashla
# Processing record 44 of set 8 | ouango
# Processing record 45 of set 8 | zhuanghe
# Processing record 46 of set 8 | nishihara
# City not found. Skipping....
# Processing record 47 of set 8 | mayskiy
# Processing record 48 of set 8 | shebunino
# Processing record 49 of set 8 | chai nat
# Processing record 50 of set 8 | srednekolymsk
# Processing record 1 of set 9 | matay
# Processing record 2 of set 9 | solnechnyy
# Processing record 3 of set 9 | muroto
# Processing record 4 of set 9 | hasaki
# Processing record 5 of set 9 | erenhot
# Processing record 6 of set 9 | airai
# Processing record 7 of set 9 | buraydah
# Processing record 8 of set 9 | bossangoa
# Processing record 9 of set 9 | sungai besar
# Processing record 10 of set 9 | tiksi
# Processing record 11 of set 9 | xam nua
# Processing record 12 of set 9 | eidfjord
# Processing record 13 of set 9 | ko samui
# Processing record 14 of set 9 | ansbach
# Processing record 15 of set 9 | cam ranh
# Processing record 16 of set 9 | lutkun
# City not found. Skipping....
# Processing record 17 of set 9 | lasa
# Processing record 18 of set 9 | tilichiki
# Processing record 19 of set 9 | uetze
# City not found. Skipping....
# Processing record 20 of set 9 | garowe
# Processing record 21 of set 9 | longyearbyen
# City not found. Skipping....
# Processing record 22 of set 9 | senj
# Processing record 23 of set 9 | adrar
# Processing record 24 of set 9 | awbari
# Processing record 25 of set 9 | sirnak
# Processing record 26 of set 9 | nizhniy baskunchak
# Processing record 27 of set 9 | milkovo
# City not found. Skipping....
# Processing record 28 of set 9 | kumano
# Processing record 29 of set 9 | evensk
# Processing record 30 of set 9 | nurota
# Processing record 31 of set 9 | belyy yar
# Processing record 32 of set 9 | zlitan
# Processing record 33 of set 9 | imeni poliny osipenko
# Processing record 34 of set 9 | mahibadhoo
# Processing record 35 of set 9 | zaysan
# Processing record 36 of set 9 | ambagarh chauki
# City not found. Skipping....
# Processing record 37 of set 9 | baiyin
# Processing record 38 of set 9 | nyurba
# Processing record 39 of set 9 | boguchany
# City not found. Skipping....
# Processing record 40 of set 9 | svetlogorsk
# City not found. Skipping....
# Processing record 41 of set 9 | myskhako
# City not found. Skipping....
# Processing record 42 of set 9 | thatta
# Processing record 43 of set 9 | shenkursk
# Processing record 44 of set 9 | quang ngai
# Processing record 45 of set 9 | netanya
# Processing record 46 of set 9 | kondinskoye
# Processing record 47 of set 9 | xuanhua
# Processing record 48 of set 9 | kloulklubed
# Processing record 49 of set 9 | zhigansk
# Processing record 50 of set 9 | haicheng
# Processing record 1 of set 10 | asyut
# Processing record 2 of set 10 | hamada
# Processing record 3 of set 10 | langres
# Processing record 4 of set 10 | plaridel
# Processing record 5 of set 10 | kollam
# Processing record 6 of set 10 | zyryanskoye
# Processing record 7 of set 10 | ust-nera
# Processing record 8 of set 10 | tazovskiy
# Processing record 9 of set 10 | sakata
# Processing record 10 of set 10 | moron
# Processing record 11 of set 10 | kulhudhuffushi
# Processing record 12 of set 10 | vardo
# Processing record 13 of set 10 | xinzhou
# Processing record 14 of set 10 | jalu
# City not found. Skipping....
# Processing record 15 of set 10 | bien hoa
# City not found. Skipping....
# Processing record 16 of set 10 | toora-khem
# Processing record 17 of set 10 | strezhevoy
# Processing record 18 of set 10 | tondano
# Processing record 19 of set 10 | namatanai
# Processing record 20 of set 10 | waddan
# City not found. Skipping....
# Processing record 21 of set 10 | berlevag
# Processing record 22 of set 10 | hambantota
# Processing record 23 of set 10 | wamba
# City not found. Skipping....
# Processing record 24 of set 10 | nerchinskiy zavod
# Processing record 25 of set 10 | omsukchan
# Processing record 26 of set 10 | beli manastir
# Processing record 27 of set 10 | bam
# Processing record 28 of set 10 | agadez
# City not found. Skipping....
# Processing record 29 of set 10 | nalut
# Processing record 30 of set 10 | eyl
# Processing record 31 of set 10 | yangambi
# Processing record 32 of set 10 | chumikan
# Processing record 33 of set 10 | chernyshevskiy
# Processing record 34 of set 10 | kushmurun
# Processing record 35 of set 10 | lindas
# Processing record 36 of set 10 | hobyo
# Processing record 37 of set 10 | fukue
# Processing record 38 of set 10 | yenagoa
# Processing record 39 of set 10 | port dickson
# Processing record 40 of set 10 | gambela
# Processing record 41 of set 10 | okha
# Processing record 42 of set 10 | hovd
# Processing record 43 of set 10 | basco
# Processing record 44 of set 10 | ormara
# Processing record 45 of set 10 | beringovskiy
# Processing record 46 of set 10 | mathbaria
# Processing record 47 of set 10 | shelopugino
# Processing record 48 of set 10 | kidal
# Processing record 49 of set 10 | ossora
# Processing record 50 of set 10 | bud
# Processing record 1 of set 11 | ostrovnoy
# City not found. Skipping....
# Processing record 2 of set 11 | pyra
# Processing record 3 of set 11 | kargasok
# Processing record 4 of set 11 | loa janan
# Processing record 5 of set 11 | chifeng
# Processing record 6 of set 11 | lodwar
# Processing record 7 of set 11 | xichang
# City not found. Skipping....
# Processing record 8 of set 11 | kharagpur
# Processing record 9 of set 11 | aykhal
# Processing record 10 of set 11 | solomenskoye
# Processing record 11 of set 11 | anadyr
# Processing record 12 of set 11 | qostanay
# Processing record 13 of set 11 | gleisdorf
# Processing record 14 of set 11 | bilma
# Processing record 15 of set 11 | lala
# Processing record 16 of set 11 | turayf
# Processing record 17 of set 11 | kavieng
# Processing record 18 of set 11 | ordu
# Processing record 19 of set 11 | maarianhamina
# Processing record 20 of set 11 | saint-andre-les-vergers
# Processing record 21 of set 11 | bitkine
# Processing record 22 of set 11 | berck
# Processing record 23 of set 11 | tokmak
# Processing record 24 of set 11 | osa
# Processing record 25 of set 11 | goundi
# Processing record 26 of set 11 | sayyan
# Processing record 27 of set 11 | kosh-agach
# Processing record 28 of set 11 | ichinohe
# Processing record 29 of set 11 | udachnyy
# Processing record 30 of set 11 | dniprovka
# Processing record 31 of set 11 | dabat
# Processing record 32 of set 11 | verkhnechusovskiye gorodki
# Processing record 33 of set 11 | jinchang
# Processing record 34 of set 11 | andijon
# Processing record 35 of set 11 | starogard gdanski
# Processing record 36 of set 11 | belaya gora
# Processing record 37 of set 11 | mugur-aksy
# Processing record 38 of set 11 | turukhansk
# Processing record 39 of set 11 | ikom
# Processing record 40 of set 11 | berezovyy
# City not found. Skipping....
# Processing record 41 of set 11 | vyssi brod
# Processing record 42 of set 11 | ust-kuyga
# Processing record 43 of set 11 | frankfurt
# Processing record 44 of set 11 | syamzha
# Processing record 45 of set 11 | zhezkazgan
# Processing record 46 of set 11 | krasnoselkup
# Processing record 47 of set 11 | bereda
# Processing record 48 of set 11 | vawkavysk
# Processing record 49 of set 11 | benghazi
# City not found. Skipping....
# Processing record 50 of set 11 | tupik
# Processing record 1 of set 12 | balabac
# Processing record 2 of set 12 | umea
# Processing record 3 of set 12 | zonguldak
# Processing record 4 of set 12 | davenda
# City not found. Skipping....
# Processing record 5 of set 12 | seoul
# Processing record 6 of set 12 | talaya
# Processing record 7 of set 12 | volga
# City not found. Skipping....
# City not found. Skipping....
# Processing record 8 of set 12 | svetlyy
# Processing record 9 of set 12 | boddam
# Processing record 10 of set 12 | panzhihua
# Processing record 11 of set 12 | krasnoarmeysk
# Processing record 12 of set 12 | chynov
# Processing record 13 of set 12 | beba
# Processing record 14 of set 12 | visnes
# City not found. Skipping....
# Processing record 15 of set 12 | kavaratti
# City not found. Skipping....
# Processing record 16 of set 12 | dukat
# Processing record 17 of set 12 | kharitonovo
# Processing record 18 of set 12 | semporna
# Processing record 19 of set 12 | kaseda
# Processing record 20 of set 12 | tuni
# Processing record 21 of set 12 | pustoshka
# Processing record 22 of set 12 | chalus
# Processing record 23 of set 12 | funadhoo
# Processing record 24 of set 12 | bandarbeyla
# Processing record 25 of set 12 | tchollire
# Processing record 26 of set 12 | miyazu
# Processing record 27 of set 12 | yanam
# Processing record 28 of set 12 | victoria
# Processing record 29 of set 12 | esil
# Processing record 30 of set 12 | lovozero
# City not found. Skipping....
# Processing record 31 of set 12 | novikovo
# Processing record 32 of set 12 | gat
# Processing record 33 of set 12 | veraval
# Processing record 34 of set 12 | shache
# Processing record 35 of set 12 | jinan
# Processing record 36 of set 12 | kyren
# Processing record 37 of set 12 | machhlishahr
# Processing record 38 of set 12 | shimoda
# Processing record 39 of set 12 | seymchan
# Processing record 40 of set 12 | surt
# Processing record 41 of set 12 | kamenka
# Processing record 42 of set 12 | wanning
# Processing record 43 of set 12 | naze
# Processing record 44 of set 12 | thongwa
# Processing record 45 of set 12 | along
# Processing record 46 of set 12 | tatawin
# Processing record 47 of set 12 | slantsy
# Processing record 48 of set 12 | berdigestyakh
# Processing record 49 of set 12 | ereymentau
# Processing record 50 of set 12 | ahtopol
# Processing record 1 of set 13 | carnot
# Processing record 2 of set 13 | haradok
# Processing record 3 of set 13 | dwarka
# Processing record 4 of set 13 | nagato
# Processing record 5 of set 13 | sorong
# Processing record 6 of set 13 | dong hoi
# Processing record 7 of set 13 | kotaparh
# Processing record 8 of set 13 | havoysund
# Processing record 9 of set 13 | kodinsk
# Processing record 10 of set 13 | kieta
# Processing record 11 of set 13 | poltava
# Processing record 12 of set 13 | yumen
# City not found. Skipping....
# City not found. Skipping....
# Processing record 13 of set 13 | pilar
# Processing record 14 of set 13 | erzurum
# Processing record 15 of set 13 | cotonou
# Processing record 16 of set 13 | zdvinsk
# Processing record 17 of set 13 | qujing
# Processing record 18 of set 13 | peleduy
# Processing record 19 of set 13 | kyaikto
# Processing record 20 of set 13 | sibolga
# Processing record 21 of set 13 | ekibastuz
# Processing record 22 of set 13 | lashio
# Processing record 23 of set 13 | batagay
# Processing record 24 of set 13 | devarkonda
# Processing record 25 of set 13 | ventspils
# Processing record 26 of set 13 | kuryk
# Processing record 27 of set 13 | wum
# City not found. Skipping....
# Processing record 28 of set 13 | biltine
# Processing record 29 of set 13 | quchan
# Processing record 30 of set 13 | masallatah
# Processing record 31 of set 13 | volchikha
# Processing record 32 of set 13 | ugoofaaru
# City not found. Skipping....
# Processing record 33 of set 13 | abha
# Processing record 34 of set 13 | severodvinsk
# Processing record 35 of set 13 | arman
# Processing record 36 of set 13 | aleksandrow kujawski
# Processing record 37 of set 13 | storforshei
# Processing record 38 of set 13 | neutraubling
# Processing record 39 of set 13 | champawat
# Processing record 40 of set 13 | kayerkan
# Processing record 41 of set 13 | faya
# Processing record 42 of set 13 | magdalena
# Processing record 43 of set 13 | pangody
# Processing record 44 of set 13 | tinosu
# Processing record 45 of set 13 | gazanjyk
# Processing record 46 of set 13 | promyshlennaya
# Processing record 47 of set 13 | severo-yeniseyskiy
# Processing record 48 of set 13 | isiro
# Processing record 49 of set 13 | petropavlovsk-kamchatskiy
# Processing record 50 of set 13 | zyryanka
# Processing record 1 of set 14 | ust-tarka
# Processing record 2 of set 14 | kannur
# Processing record 3 of set 14 | weinan
# Processing record 4 of set 14 | aqtobe
# Processing record 5 of set 14 | basoko
# Processing record 6 of set 14 | karwar
# Processing record 7 of set 14 | erzin
# Processing record 8 of set 14 | lakhdenpokhya
# Processing record 9 of set 14 | sakskobing
# City not found. Skipping....
# Processing record 10 of set 14 | tura
# City not found. Skipping....
# Processing record 11 of set 14 | shakhtinsk
# Processing record 12 of set 14 | manokwari
# Processing record 13 of set 14 | hudiksvall
# Processing record 14 of set 14 | esso
# Processing record 15 of set 14 | yerkoy
# Processing record 16 of set 14 | larsnes
# Processing record 17 of set 14 | burdur
# Processing record 18 of set 14 | batagay-alyta
# Processing record 19 of set 14 | nadym
# Processing record 20 of set 14 | aksarka
# Processing record 21 of set 14 | thinadhoo
# Processing record 22 of set 14 | mangrul pir
# Processing record 23 of set 14 | baykit
# City not found. Skipping....
# Processing record 24 of set 14 | wabrzezno
# Processing record 25 of set 14 | bluff
# Processing record 26 of set 14 | hobart
# Processing record 27 of set 14 | new norfolk
# Processing record 28 of set 14 | albany
# City not found. Skipping....
# Processing record 29 of set 14 | denpasar
# Processing record 30 of set 14 | esperance
# Processing record 31 of set 14 | carnarvon
# Processing record 32 of set 14 | margate
# Processing record 33 of set 14 | busselton
# City not found. Skipping....
# Processing record 34 of set 14 | cap malheureux
# Processing record 35 of set 14 | bredasdorp
# Processing record 36 of set 14 | westport
# Processing record 37 of set 14 | hithadhoo
# Processing record 38 of set 14 | saint-philippe
# Processing record 39 of set 14 | mount isa
# Processing record 40 of set 14 | kalianget
# Processing record 41 of set 14 | bengkulu
# Processing record 42 of set 14 | kruisfontein
# Processing record 43 of set 14 | warwick
# Processing record 44 of set 14 | broken hill
# Processing record 45 of set 14 | bowen
# Processing record 46 of set 14 | luebo
# Processing record 47 of set 14 | port lincoln
# Processing record 48 of set 14 | port elizabeth
# Processing record 49 of set 14 | tuatapere
# Processing record 50 of set 14 | benguela
# Processing record 1 of set 15 | xai-xai
# City not found. Skipping....
# Processing record 2 of set 15 | bambous virieux
# Processing record 3 of set 15 | launceston
# Processing record 4 of set 15 | vila
# Processing record 5 of set 15 | mahebourg
# Processing record 6 of set 15 | luderitz
# Processing record 7 of set 15 | east london
# Processing record 8 of set 15 | manggar
# Processing record 9 of set 15 | gizo
# Processing record 10 of set 15 | dekar
# Processing record 11 of set 15 | mlonggo
# Processing record 12 of set 15 | port shepstone
# Processing record 13 of set 15 | chama
# Processing record 14 of set 15 | samarai
# City not found. Skipping....
# Processing record 15 of set 15 | saurimo
# Processing record 16 of set 15 | nacala
# Processing record 17 of set 15 | souillac
# City not found. Skipping....
# Processing record 18 of set 15 | morehead
# Processing record 19 of set 15 | ahipara
# Processing record 20 of set 15 | mitsamiouli
# Processing record 21 of set 15 | koumac
# Processing record 22 of set 15 | port alfred
# Processing record 23 of set 15 | kununurra
# Processing record 24 of set 15 | mount gambier
# Processing record 25 of set 15 | nkhotakota
# Processing record 26 of set 15 | montepuez
# Processing record 27 of set 15 | grand gaube
# Processing record 28 of set 15 | katherine
# Processing record 29 of set 15 | broome
# Processing record 30 of set 15 | quelimane
# Processing record 31 of set 15 | wollongong
# Processing record 32 of set 15 | asau
# Processing record 33 of set 15 | sakaraha
# City not found. Skipping....
# Processing record 34 of set 15 | te anau
# Processing record 35 of set 15 | opuwo
# Processing record 36 of set 15 | henties bay
# Processing record 37 of set 15 | hervey bay
# Processing record 38 of set 15 | mackay
# Processing record 39 of set 15 | antalaha
# Processing record 40 of set 15 | yulara
# Processing record 41 of set 15 | kendari
# Processing record 42 of set 15 | tshane
# City not found. Skipping....
# Processing record 43 of set 15 | mbala
# Processing record 44 of set 15 | innisfail
# Processing record 45 of set 15 | kaeo
# Processing record 46 of set 15 | portland
# Processing record 47 of set 15 | madang
# Processing record 48 of set 15 | sokoni
# City not found. Skipping....
# Processing record 49 of set 15 | port hedland
# Processing record 50 of set 15 | karratha
# Processing record 1 of set 16 | nelson bay
# Processing record 2 of set 16 | kalakamati
# Processing record 3 of set 16 | tual
# City not found. Skipping....
# Processing record 4 of set 16 | byumba
# Processing record 5 of set 16 | lakatoro
# Processing record 6 of set 16 | lata
# Processing record 7 of set 16 | thamaga
# Processing record 8 of set 16 | waingapu
# Processing record 9 of set 16 | brazzaville
# Processing record 10 of set 16 | poum
# Processing record 11 of set 16 | isangel
# Processing record 12 of set 16 | labuhan
# Processing record 13 of set 16 | saldanha
# Processing record 14 of set 16 | sefophe
# Processing record 15 of set 16 | pangkalanbuun
# Processing record 16 of set 16 | beloha
# Processing record 17 of set 16 | kirakira
# Processing record 18 of set 16 | pringsewu
# Processing record 19 of set 16 | russell
# Processing record 20 of set 16 | namibe
# Processing record 21 of set 16 | lamu
# Processing record 22 of set 16 | lumeje
# Processing record 23 of set 16 | galesong
# Processing record 24 of set 16 | burnie
# City not found. Skipping....
# Processing record 25 of set 16 | bambanglipuro
# Processing record 26 of set 16 | port augusta
# Processing record 27 of set 16 | saint-pierre
# Processing record 28 of set 16 | hokitika
# Processing record 29 of set 16 | kamina
# Processing record 30 of set 16 | merauke
# Processing record 31 of set 16 | ambilobe
# Processing record 32 of set 16 | de aar
# Processing record 33 of set 16 | omboue
# Processing record 34 of set 16 | inhambane
# Processing record 35 of set 16 | port pirie
# Processing record 36 of set 16 | daru
# Processing record 37 of set 16 | micheweni
# Processing record 38 of set 16 | kisangani
# Processing record 39 of set 16 | auki
# Processing record 40 of set 16 | dunedin
# Processing record 41 of set 16 | gweta
# Processing record 42 of set 16 | sola
# Processing record 43 of set 16 | mossendjo
# Processing record 44 of set 16 | le port
# City not found. Skipping....
# Processing record 45 of set 16 | waipawa
# Processing record 46 of set 16 | mangai
# Processing record 47 of set 16 | lorengau
# Processing record 48 of set 16 | batemans bay
# Processing record 49 of set 16 | alice springs
# Processing record 50 of set 16 | praya
# Processing record 1 of set 17 | mariental
# Processing record 2 of set 17 | yeppoon
# Processing record 3 of set 17 | upington
# Processing record 4 of set 17 | buala
# Processing record 5 of set 17 | mutoko
# City not found. Skipping....
# City not found. Skipping....
# Processing record 6 of set 17 | ngerengere
# Processing record 7 of set 17 | boende
# Processing record 8 of set 17 | matara
# Processing record 9 of set 17 | kariba
# Processing record 10 of set 17 | kencong
# Processing record 11 of set 17 | kaitangata
# Processing record 12 of set 17 | porirua
# Processing record 13 of set 17 | walvis bay
# Processing record 14 of set 17 | chitipa
# Processing record 15 of set 17 | ondjiva
# Processing record 16 of set 17 | chitungwiza
# Processing record 17 of set 17 | mwinilunga
# Processing record 18 of set 17 | quatre cocos

# %%
#Convert Raw Data to DataFrame
  #Export the city data into a .csv.
  #Display the DataFrame

# %%
#We indicate the number of values that each list has, as requested:
print(len(cities1))
print(len(cloudiness))
print(len(countries))
print(len(dates))
print(len(humidity))
print(len(lats))
print(len(lng))
print(len(max_temp))
print(len(speed_w))
# Out:
# 819
# 819
# 819
# 819
# 819
# 819
# 819
# 819
# 819

# %%
#We build a dictionary, and then a dataframe based on the lists that we created.
dataframe = {"City":cities1, "Cloudiness":cloudiness, "Country":countries, "Date":dates, "Humidity":humidity, "Lat":lats, "Lng":lng, "Max Temp":max_temp, "Wind Speed": speed_w}
dataframe = pd.DataFrame(dataframe)
dataframe.to_csv("1.dataframe.csv", index = False , header = True)
dataframe
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Punta Arenas          75      CL  1604717233        61 -53.15  -70.92
# 1    Arraial do Cabo          98      BR  1604717485        74 -22.97  -42.03
# 2          Jamestown           1      US  1604717210        54  42.10  -79.24
# 3             Avarua          82      CK  1604717456        83 -21.21 -159.78
# 4            Cabrobó          90      BR  1604717896        65  -8.51  -39.31
# ..               ...         ...     ...         ...       ...    ...     ...
# 814          Chitipa          23      MW  1604718184        70  -9.70   33.27
# 815          Ondjiva           0      AO  1604718184        31 -17.07   15.73
# 816      Chitungwiza           0      ZW  1604718185        53 -18.01   31.08
# 817       Mwinilunga          43      ZM  1604718185        85 -11.74   24.43
# 818     Quatre Cocos          75      MU  1604718185        88 -20.21   57.76
#
#      Max Temp  Wind Speed
# 0       48.20        8.05
# 1       70.97        7.63
# 2       55.40        8.05
# 3       77.00        4.70
# 4       79.21       21.54
# ..        ...         ...
# 814     63.82        5.84
# 815     69.84        6.76
# 816     69.01        5.01
# 817     62.04        1.61
# 818     73.00        6.93
#
# [819 rows x 9 columns]

# %%
# Plotting the Data
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

# %%
#City Latitude vs. Max Temperature 
#We create the scatter plot and add the necessary labels & formatting changes: 

plt.scatter(dataframe["Lat"],dataframe["Max Temp"],edgecolors="black",linewidth=0.8)
plt.title("City Latitude vs. Max Temperature (11/06/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("2.Lat_vs_Temp.png")
plt.show()

# %%
#City Latitude vs. Humidity 
#We create the scatter plot and add the necessary labels & formatting changes: 

plt.scatter(dataframe["Lat"],dataframe["Humidity"],edgecolors="black",linewidth=0.8)
plt.title("City Latitude vs. Humidity (11/06/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("3.Lat_vs_Humidity.png")
plt.show()

# %%
#City Latitude vs. Cloudiness 
#We create the scatter plot and add the necessary labels & formatting changes: 

plt.scatter(dataframe["Lat"],dataframe["Cloudiness"],edgecolors="black",linewidth=0.8)
plt.title("City Latitude vs. Cloudiness (11/06/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("4.Lat_vs_Cloudiness.png")
plt.show()

# %%
#City Latitude vs. Wind Speed 
#We create the scatter plot and add the necessary labels & formatting changes: 

plt.scatter(dataframe["Lat"],dataframe["Wind Speed"],edgecolors="black",linewidth=0.8)
plt.title("City Latitude vs. Wind Speed (11/06/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("5.Lat_vs_WindSpeed.png")
plt.show()

# %%
#LINEAR REGRESSION CHARTS
#We create two dataframs. One with the cities above the equator line (northern hemisphere), and one with cities below the equator line (southern hemisphere)

Northern_Hemisphere = dataframe.loc[dataframe["Lat"]>0]
Southern_Hemisphere = dataframe.loc[dataframe["Lat"]<0]

# %%
#We import scipy.stats
from scipy.stats import linregress

#LINEAR REGRESSION #1 - Northern Hemisphere - Temperature (F) vs.Latitude

#We calculate the correlation coefficient, and  the regression values:
slope, intercept, rvalue, pvalue, stderr = linregress(Northern_Hemisphere["Lat"], Northern_Hemisphere["Max Temp"])
x_values = Northern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Northern_Hemisphere["Max Temp"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(0, 0), fontsize=15, color='red')
plt.ylabel("Northern Hemisphere - Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Northern Hemisphere - Temperature (F) vs.Latitude")
plt.savefig("6.North_Temp_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #2 - Southern Hemisphere - Temperature (F) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Southern_Hemisphere["Lat"], Southern_Hemisphere["Max Temp"])
x_values = Southern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Southern_Hemisphere["Max Temp"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(-50, 90), fontsize=15, color='red')
plt.ylabel("Southern Hemisphere - Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Southern Hemisphere - Temperature (F) vs. Latitude")
plt.savefig("7.South_Temp_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #3 - Northern Hemisphere - Humidity (%) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Northern_Hemisphere["Lat"], Northern_Hemisphere["Humidity"])
x_values = Northern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Northern_Hemisphere["Humidity"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(50, 15), fontsize=15, color='red')
plt.ylabel("Northern Hemisphere - Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.savefig("8.North_Humidity_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #4 - Southern Hemisphere - Humidity (%) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Southern_Hemisphere["Lat"], Southern_Hemisphere["Humidity"])
x_values = Southern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Southern_Hemisphere["Humidity"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(-50, 10), fontsize=15, color='red')
plt.ylabel("Southern Hemisphere - Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.savefig("9.South_Humidity_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #5 - Northern Hemisphere - Cloudiness (%) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Northern_Hemisphere["Lat"], Northern_Hemisphere["Cloudiness"])
x_values = Northern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Northern_Hemisphere["Cloudiness"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(50, 10), fontsize=15, color='red')
plt.ylabel("Northern Hemisphere - Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.savefig("10.North_Cloudiness_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #6 - Southern Hemisphere - Cloudiness (%) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Southern_Hemisphere["Lat"], Southern_Hemisphere["Cloudiness"])
x_values = Southern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Southern_Hemisphere["Cloudiness"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(-50, 50), fontsize=15, color='red')
plt.ylabel("Southern Hemisphere - Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.savefig("11.South_Cloudiness_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #7 - Northern Hemisphere - Wind Speed (mph) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Northern_Hemisphere["Lat"], Northern_Hemisphere["Wind Speed"])
x_values = Northern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Northern_Hemisphere["Wind Speed"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(15, 32), fontsize=15, color='red')
plt.ylabel("Northern Hemisphere - Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.savefig("12.North_WindSpeed_vs_Lat.png")
plt.show()

# %%
#LINEAR REGRESSION #8 - Southern Hemisphere - Wind Speed (mph) vs. Latitude

#We calculate the correlation coefficient, and  the regress values:
slope, intercept, rvalue, pvalue, stderr = linregress(Southern_Hemisphere["Lat"], Southern_Hemisphere["Wind Speed"])
x_values = Southern_Hemisphere["Lat"]
regress_values = slope * x_values + intercept 

#We write down the equation
eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

#We draft the linear regression model: 
plt.scatter(x_values, Southern_Hemisphere["Wind Speed"])
plt.plot(x_values, regress_values, color="red")
plt.annotate(eq,(-50, 18), fontsize=15, color='red')
plt.ylabel("Southern Hemisphere - Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.savefig("13.South_WindSpeed_vs_Lat.png")
plt.show()
